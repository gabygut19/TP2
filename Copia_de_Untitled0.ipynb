# %% [markdown]
# <a href="https://colab.research.google.com/github/gabygut19/TP2/blob/master/Copia_de_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
surveys_df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00491/15.csv")
surveys_df.head()
surveys_df.columns
media = surveys_df['sex'].mean()
desvia = surveys_df['sex'].std()
total =surveys_df['sex'].count()
print(media,desvia,total)
